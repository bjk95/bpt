# %% [markdown]
# # Chess BPT data cleansing
#
# Downloaded [Lichess elite database](https://database.nikonoel.fr/)

# %%
import chess.pgn
import os
from schemas import GameState

EMPTY = '.'

def parse_game(game: str, n: int) -> list[GameState]:
    g = game.split(' ')
    moves = g[1:]
    board = chess.Board()
    result = g[0]
    
    game_states: list[GameState] = []
    for i, move in enumerate(moves):
        first_move_idx = i - n if i - n > 0 else 0
        board.push_san(move)
        # Create an 8x8 board representation
        board_state = []
        for rank in range(8):
            rank_squares = []
            for file in range(8):
                square = chess.square(file, 7-rank)  # chess library uses 0-7 for ranks from bottom to top
                piece = board.piece_at(square)
                if piece is None:
                    rank_squares.append(EMPTY)
                else:
                    piece_color = "white" if piece.color == chess.WHITE else "black"
                    piece_type = chess.piece_name(piece.piece_type)
                    rank_squares.append(f"{piece_color} {piece_type}")
            board_state.append(rank_squares)
            
        m = [EMPTY] * (n + 1)
        for j, move_text in enumerate(moves[first_move_idx:i+1]):
            # Determine color based on move index - white moves first in chess
            move_index = first_move_idx + j
            color = "w" if move_index % 2 == 0 else "b"
            m[j] = f"{move_text}:{color}"
            
            
        # Create a GameState with the current board state
        game_state = GameState(
            board=board_state,
            result=result,
            moves=reversed(m)
        )
        game_states.append(game_state)
    
    return game_states

def extract_formatted_games_from_pgn(pgn_file:str, possible_moves: set[str], sample: int | None = None) -> list[str]:
    formatted_games = []
    count = 0
    
    with open(pgn_file, "r", encoding="utf-8") as file:
        while True:
            if sample is not None and count >= sample:
                break
            if count % 100 == 0:
                print(f'{count} games')
            game = chess.pgn.read_game(file)
            if game is None:
                break  # End of file

            # Extract the result
            result = game.headers.get("Result", "*")
            
            # Skip games with unknown results
            if result == "*":
                continue
                
            winner = None
            if result == "1-0":
                winner = WHITE
            elif result == "0-1":
                winner = BLACK
            elif result == "1/2-1/2":
                winner = "draw"
            else:
                continue  # Skip any other unexpected result format

            board = game.board()
            moves = []
            for move in game.mainline_moves():
                moves.append(board.san(move))
                board.push(move)

            # Format as: winner START moves END
            game_text = f"{winner} {' '.join(moves)}"
            games_states = parse_game(game_text, 10)
            formatted_games.extend(games_states)
            possible_moves.update(moves)
            count += 1
    
    return formatted_games, possible_moves

WHITE = "white"
BLACK = "black"
START = "<start>"
END = "<end>"
# Example usage
pgn_file = "data/raw/lichess_elite_2022-02.pgn"  # Replace with your file
games, possible_moves = extract_formatted_games_from_pgn(pgn_file, set(), 3)

# Print first 5 games' moves
for i, game_moves in enumerate(games):
    print(f"Game {i+1}: {game_moves}\n")
# Out:
# 0 games
# Game 1: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', 'black bishop', 'black knight', 'black rook'], ['black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', 'white pawn', 'white pawn', 'white pawn', 'white pawn'], ['white rook', 'white knight', 'white bishop', 'white queen', 'white king', 'white bishop', 'white knight', 'white rook']] moves=['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'd4:w'] result='draw'
#
# Game 2: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', 'black bishop', '.', 'black rook'], ['black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', '.', 'black knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', 'white pawn', 'white pawn', 'white pawn', 'white pawn'], ['white rook', 'white knight', 'white bishop', 'white queen', 'white king', 'white bishop', 'white knight', 'white rook']] moves=['.', '.', '.', '.', '.', '.', '.', '.', '.', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 3: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', 'black bishop', '.', 'black rook'], ['black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', '.', 'black knight', '.', '.'], ['.', '.', '.', '.', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', 'white pawn', 'white pawn', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', 'white bishop', 'white knight', 'white rook']] moves=['.', '.', '.', '.', '.', '.', '.', '.', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 4: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', 'black bishop', '.', 'black rook'], ['black pawn', 'black pawn', 'black pawn', 'black pawn', '.', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', '.', '.', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', 'white pawn', 'white pawn', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', 'white bishop', 'white knight', 'white rook']] moves=['.', '.', '.', '.', '.', '.', '.', 'e6:b', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 5: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', 'black bishop', '.', 'black rook'], ['black pawn', 'black pawn', 'black pawn', 'black pawn', '.', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', '.', '.', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', '.', '.', '.'], ['.', '.', '.', '.', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', '.', 'white pawn', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', 'white bishop', 'white knight', 'white rook']] moves=['.', '.', '.', '.', '.', '.', 'e3:w', 'e6:b', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 6: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', '.', '.', 'black rook'], ['black pawn', 'black pawn', 'black pawn', 'black pawn', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', '.', '.', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', '.', '.', '.'], ['.', '.', '.', '.', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', '.', 'white pawn', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', 'white bishop', 'white knight', 'white rook']] moves=['.', '.', '.', '.', '.', 'Be7:b', 'e3:w', 'e6:b', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 7: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', '.', '.', 'black rook'], ['black pawn', 'black pawn', 'black pawn', 'black pawn', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', '.', '.', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', '.', '.', '.'], ['.', '.', '.', 'white bishop', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', '.', 'white pawn', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', '.', 'white knight', 'white rook']] moves=['.', '.', '.', '.', 'Bd3:w', 'Be7:b', 'e3:w', 'e6:b', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 8: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', '.', '.', 'black rook'], ['black pawn', 'black pawn', 'black pawn', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', '.', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', '.', '.', '.'], ['.', '.', '.', 'white bishop', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', '.', 'white pawn', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', '.', 'white knight', 'white rook']] moves=['.', '.', '.', 'd5:b', 'Bd3:w', 'Be7:b', 'e3:w', 'e6:b', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 9: board=[['black rook', 'black knight', 'black bishop', 'black queen', 'black king', '.', '.', 'black rook'], ['black pawn', 'black pawn', 'black pawn', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', '.', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', '.', 'white bishop', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', '.', '.', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', '.', 'white knight', 'white rook']] moves=['.', '.', 'f4:w', 'd5:b', 'Bd3:w', 'Be7:b', 'e3:w', 'e6:b', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 10: board=[['black rook', 'black knight', 'black bishop', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black pawn', 'black pawn', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', '.', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', '.', 'white bishop', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', '.', '.', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', '.', 'white knight', 'white rook']] moves=['.', 'O-O:b', 'f4:w', 'd5:b', 'Bd3:w', 'Be7:b', 'e3:w', 'e6:b', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 11: board=[['black rook', 'black knight', 'black bishop', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black pawn', 'black pawn', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', '.', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', '.', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', '.', '.', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', '.', '.', 'white rook']] moves=['Nf3:w', 'O-O:b', 'f4:w', 'd5:b', 'Bd3:w', 'Be7:b', 'e3:w', 'e6:b', 'Bg5:w', 'Nf6:b', 'd4:w'] result='draw'
#
# Game 12: board=[['black rook', 'black knight', 'black bishop', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black pawn', '.', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', '.', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', 'white pawn', '.', '.', '.', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', '.', '.', 'white rook']] moves=['c5:b', 'Nf3:w', 'O-O:b', 'f4:w', 'd5:b', 'Bd3:w', 'Be7:b', 'e3:w', 'e6:b', 'Bg5:w', 'Nf6:b'] result='draw'
#
# Game 13: board=[['black rook', 'black knight', 'black bishop', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black pawn', '.', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', '.', '.', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', '.', '.', 'white rook']] moves=['c3:w', 'c5:b', 'Nf3:w', 'O-O:b', 'f4:w', 'd5:b', 'Bd3:w', 'Be7:b', 'e3:w', 'e6:b', 'Bg5:w'] result='draw'
#
# Game 14: board=[['black rook', 'black knight', 'black bishop', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', '.', '.', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', '.', '.', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', 'white queen', 'white king', '.', '.', 'white rook']] moves=['b6:b', 'c3:w', 'c5:b', 'Nf3:w', 'O-O:b', 'f4:w', 'd5:b', 'Bd3:w', 'Be7:b', 'e3:w', 'e6:b'] result='draw'
#
# Game 15: board=[['black rook', 'black knight', 'black bishop', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', '.', '.', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', '.', 'white king', '.', '.', 'white rook']] moves=['Qe2:w', 'b6:b', 'c3:w', 'c5:b', 'Nf3:w', 'O-O:b', 'f4:w', 'd5:b', 'Bd3:w', 'Be7:b', 'e3:w'] result='draw'
#
# Game 16: board=[['black rook', 'black knight', '.', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', 'white knight', '.', '.', 'white king', '.', '.', 'white rook']] moves=['Bb7:b', 'Qe2:w', 'b6:b', 'c3:w', 'c5:b', 'Nf3:w', 'O-O:b', 'f4:w', 'd5:b', 'Bd3:w', 'Be7:b'] result='draw'
#
# Game 17: board=[['black rook', 'black knight', '.', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', '.', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', 'white king', '.', '.', 'white rook']] moves=['Nbd2:w', 'Bb7:b', 'Qe2:w', 'b6:b', 'c3:w', 'c5:b', 'Nf3:w', 'O-O:b', 'f4:w', 'd5:b', 'Bd3:w'] result='draw'
#
# Game 18: board=[['black rook', '.', '.', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', 'white king', '.', '.', 'white rook']] moves=['Nbd7:b', 'Nbd2:w', 'Bb7:b', 'Qe2:w', 'b6:b', 'c3:w', 'c5:b', 'Nf3:w', 'O-O:b', 'f4:w', 'd5:b'] result='draw'
#
# Game 19: board=[['black rook', '.', '.', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', 'black pawn'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', '.'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['O-O:w', 'Nbd7:b', 'Nbd2:w', 'Bb7:b', 'Qe2:w', 'b6:b', 'c3:w', 'c5:b', 'Nf3:w', 'O-O:b', 'f4:w'] result='draw'
#
# Game 20: board=[['black rook', '.', '.', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', '.', 'black pawn', 'black pawn', '.', '.', 'white bishop', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', '.'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['h6:b', 'O-O:w', 'Nbd7:b', 'Nbd2:w', 'Bb7:b', 'Qe2:w', 'b6:b', 'c3:w', 'c5:b', 'Nf3:w', 'O-O:b'] result='draw'
#
# Game 21: board=[['black rook', '.', '.', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', '.', 'black pawn', 'black pawn', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Bh4:w', 'h6:b', 'O-O:w', 'Nbd7:b', 'Nbd2:w', 'Bb7:b', 'Qe2:w', 'b6:b', 'c3:w', 'c5:b', 'Nf3:w'] result='draw'
#
# Game 22: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', '.', 'black pawn', 'black pawn', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Rc8:b', 'Bh4:w', 'h6:b', 'O-O:w', 'Nbd7:b', 'Nbd2:w', 'Bb7:b', 'Qe2:w', 'b6:b', 'c3:w', 'c5:b'] result='draw'
#
# Game 23: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', '.', 'black pawn', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Ne5:w', 'Rc8:b', 'Bh4:w', 'h6:b', 'O-O:w', 'Nbd7:b', 'Nbd2:w', 'Bb7:b', 'Qe2:w', 'b6:b', 'c3:w'] result='draw'
#
# Game 24: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', '.', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', 'white bishop', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['c4:b', 'Ne5:w', 'Rc8:b', 'Bh4:w', 'h6:b', 'O-O:w', 'Nbd7:b', 'Nbd2:w', 'Bb7:b', 'Qe2:w', 'b6:b'] result='draw'
#
# Game 25: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', 'black pawn', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', '.', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', 'white bishop', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Bc2:w', 'c4:b', 'Ne5:w', 'Rc8:b', 'Bh4:w', 'h6:b', 'O-O:w', 'Nbd7:b', 'Nbd2:w', 'Bb7:b', 'Qe2:w'] result='draw'
#
# Game 26: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', 'white bishop', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['b5:b', 'Bc2:w', 'c4:b', 'Ne5:w', 'Rc8:b', 'Bh4:w', 'h6:b', 'O-O:w', 'Nbd7:b', 'Nbd2:w', 'Bb7:b'] result='draw'
#
# Game 27: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', 'black king', '.'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', '.', 'white pawn', 'white rook', '.', '.'], ['white pawn', 'white pawn', 'white bishop', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Rf3:w', 'b5:b', 'Bc2:w', 'c4:b', 'Ne5:w', 'Rc8:b', 'Bh4:w', 'h6:b', 'O-O:w', 'Nbd7:b', 'Nbd2:w'] result='draw'
#
# Game 28: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', '.', 'white pawn', 'white rook', '.', '.'], ['white pawn', 'white pawn', 'white bishop', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Kh8:b', 'Rf3:w', 'b5:b', 'Bc2:w', 'c4:b', 'Ne5:w', 'Rc8:b', 'Bh4:w', 'h6:b', 'O-O:w', 'Nbd7:b'] result='draw'
#
# Game 29: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', 'black knight', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', 'white rook'], ['white pawn', 'white pawn', 'white bishop', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Rh3:w', 'Kh8:b', 'Rf3:w', 'b5:b', 'Bc2:w', 'c4:b', 'Ne5:w', 'Rc8:b', 'Bh4:w', 'h6:b', 'O-O:w'] result='draw'
#
# Game 30: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'black knight', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', 'white rook'], ['white pawn', 'white pawn', 'white bishop', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Ne4:b', 'Rh3:w', 'Kh8:b', 'Rf3:w', 'b5:b', 'Bc2:w', 'c4:b', 'Ne5:w', 'Rc8:b', 'Bh4:w', 'h6:b'] result='draw'
#
# Game 31: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', 'black knight', 'black bishop', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white bishop', 'white pawn', '.', 'white bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', 'white rook'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Bxe4:w', 'Ne4:b', 'Rh3:w', 'Kh8:b', 'Rf3:w', 'b5:b', 'Bc2:w', 'c4:b', 'Ne5:w', 'Rc8:b', 'Bh4:w'] result='draw'
#
# Game 32: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', 'black knight', '.', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', 'white knight', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white bishop', 'white pawn', '.', 'black bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', 'white rook'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Bxh4:b', 'Bxe4:w', 'Ne4:b', 'Rh3:w', 'Kh8:b', 'Rf3:w', 'b5:b', 'Bc2:w', 'c4:b', 'Ne5:w', 'Rc8:b'] result='draw'
#
# Game 33: board=[['.', '.', 'black rook', 'black queen', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', 'white knight', '.', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white bishop', 'white pawn', '.', 'black bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', 'white rook'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Nxd7:w', 'Bxh4:b', 'Bxe4:w', 'Ne4:b', 'Rh3:w', 'Kh8:b', 'Rf3:w', 'b5:b', 'Bc2:w', 'c4:b', 'Ne5:w'] result='draw'
#
# Game 34: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', 'black queen', '.', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', 'black pawn', '.', 'black pawn', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white bishop', 'white pawn', '.', 'black bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', 'white rook'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Qxd7:b', 'Nxd7:w', 'Bxh4:b', 'Bxe4:w', 'Ne4:b', 'Rh3:w', 'Kh8:b', 'Rf3:w', 'b5:b', 'Bc2:w', 'c4:b'] result='draw'
#
# Game 35: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', 'black queen', '.', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', 'black pawn', '.', 'white bishop', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'black bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', 'white rook'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Bxd5:w', 'Qxd7:b', 'Nxd7:w', 'Bxh4:b', 'Bxe4:w', 'Ne4:b', 'Rh3:w', 'Kh8:b', 'Rf3:w', 'b5:b', 'Bc2:w'] result='draw'
#
# Game 36: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', '.', '.', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', 'black pawn', '.', 'black queen', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'black bishop'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', 'white rook'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Qxd5:b', 'Bxd5:w', 'Qxd7:b', 'Nxd7:w', 'Bxh4:b', 'Bxe4:w', 'Ne4:b', 'Rh3:w', 'Kh8:b', 'Rf3:w', 'b5:b'] result='draw'
#
# Game 37: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', '.', '.', 'black pawn', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', 'black pawn', '.', 'black queen', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['Rxh4:w', 'Qxd5:b', 'Bxd5:w', 'Qxd7:b', 'Nxd7:w', 'Bxh4:b', 'Bxe4:w', 'Ne4:b', 'Rh3:w', 'Kh8:b', 'Rf3:w'] result='draw'
#
# Game 38: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', 'black pawn', '.', 'black queen', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['white rook', '.', '.', '.', '.', '.', 'white king', '.']] moves=['f6:b', 'Rxh4:w', 'Qxd5:b', 'Bxd5:w', 'Qxd7:b', 'Nxd7:w', 'Bxh4:b', 'Bxe4:w', 'Ne4:b', 'Rh3:w', 'Kh8:b'] result='draw'
#
# Game 39: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['black pawn', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', 'black pawn', '.', 'black queen', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Rf1:w', 'f6:b', 'Rxh4:w', 'Qxd5:b', 'Bxd5:w', 'Qxd7:b', 'Nxd7:w', 'Bxh4:b', 'Bxe4:w', 'Ne4:b', 'Rh3:w'] result='draw'
#
# Game 40: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['black pawn', 'black pawn', '.', 'black queen', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', '.', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', 'white pawn', '.', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['a5:b', 'Rf1:w', 'f6:b', 'Rxh4:w', 'Qxd5:b', 'Bxd5:w', 'Qxd7:b', 'Nxd7:w', 'Bxh4:b', 'Bxe4:w', 'Ne4:b'] result='draw'
#
# Game 41: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', '.', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['black pawn', 'black pawn', '.', 'black queen', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', '.', '.', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['e4:w', 'a5:b', 'Rf1:w', 'f6:b', 'Rxh4:w', 'Qxd5:b', 'Bxd5:w', 'Qxd7:b', 'Nxd7:w', 'Bxh4:b', 'Bxe4:w'] result='draw'
#
# Game 42: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', '.', '.', 'black queen', 'black pawn', 'black pawn', '.', 'black pawn'], ['black pawn', 'black pawn', '.', '.', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', '.', '.', '.', '.'], ['white pawn', 'white pawn', '.', 'white knight', 'white queen', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Qd6:b', 'e4:w', 'a5:b', 'Rf1:w', 'f6:b', 'Rxh4:w', 'Qxd5:b', 'Bxd5:w', 'Qxd7:b', 'Nxd7:w', 'Bxh4:b'] result='draw'
#
# Game 43: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', '.', '.', 'black queen', 'black pawn', 'black pawn', '.', 'black pawn'], ['black pawn', 'black pawn', '.', '.', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', '.', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', 'white queen', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Nf3:w', 'Qd6:b', 'e4:w', 'a5:b', 'Rf1:w', 'f6:b', 'Rxh4:w', 'Qxd5:b', 'Bxd5:w', 'Qxd7:b', 'Nxd7:w'] result='draw'
#
# Game 44: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', '.', '.', 'black queen', 'black pawn', 'black pawn', '.', 'black pawn'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black pawn', 'black pawn', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', '.', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', 'white queen', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['b4:b', 'Nf3:w', 'Qd6:b', 'e4:w', 'a5:b', 'Rf1:w', 'f6:b', 'Rxh4:w', 'Qxd5:b', 'Bxd5:w', 'Qxd7:b'] result='draw'
#
# Game 45: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', '.', '.', 'black queen', 'black pawn', 'black pawn', '.', 'black pawn'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black pawn', 'black pawn', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', '.', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Qe3:w', 'b4:b', 'Nf3:w', 'Qd6:b', 'e4:w', 'a5:b', 'Rf1:w', 'f6:b', 'Rxh4:w', 'Qxd5:b', 'Bxd5:w'] result='draw'
#
# Game 46: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black pawn', 'black pawn', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', '.', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', 'white king', '.']] moves=['Qb6:b', 'Qe3:w', 'b4:b', 'Nf3:w', 'Qd6:b', 'e4:w', 'a5:b', 'Rf1:w', 'f6:b', 'Rxh4:w', 'Qxd5:b'] result='draw'
#
# Game 47: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black pawn', 'black pawn', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', '.', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['Kh1:w', 'Qb6:b', 'Qe3:w', 'b4:b', 'Nf3:w', 'Qd6:b', 'e4:w', 'a5:b', 'Rf1:w', 'f6:b', 'Rxh4:w'] result='draw'
#
# Game 48: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'black pawn', 'black pawn', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['.', '.', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', '.', '.', 'white pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['a4:b', 'Kh1:w', 'Qb6:b', 'Qe3:w', 'b4:b', 'Nf3:w', 'Qd6:b', 'e4:w', 'a5:b', 'Rf1:w', 'f6:b'] result='draw'
#
# Game 49: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'black pawn', 'black pawn', 'white pawn', 'white pawn', 'white pawn', 'white pawn', 'white rook'], ['.', '.', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['g4:w', 'a4:b', 'Kh1:w', 'Qb6:b', 'Qe3:w', 'b4:b', 'Nf3:w', 'Qd6:b', 'e4:w', 'a5:b', 'Rf1:w'] result='draw'
#
# Game 50: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black pawn', 'black pawn', 'white pawn', 'white pawn', 'white pawn', 'white pawn', 'white rook'], ['black pawn', '.', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['white pawn', 'white pawn', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['a3:b', 'g4:w', 'a4:b', 'Kh1:w', 'Qb6:b', 'Qe3:w', 'b4:b', 'Nf3:w', 'Qd6:b', 'e4:w', 'a5:b'] result='draw'
#
# Game 51: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black pawn', 'black pawn', 'white pawn', 'white pawn', 'white pawn', 'white pawn', 'white rook'], ['white pawn', '.', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['white pawn', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['bxa3:w', 'a3:b', 'g4:w', 'a4:b', 'Kh1:w', 'Qb6:b', 'Qe3:w', 'b4:b', 'Nf3:w', 'Qd6:b', 'e4:w'] result='draw'
#
# Game 52: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white pawn', 'white pawn', 'white pawn', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['white pawn', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['b3:b', 'bxa3:w', 'a3:b', 'g4:w', 'a4:b', 'Kh1:w', 'Qb6:b', 'Qe3:w', 'b4:b', 'Nf3:w', 'Qd6:b'] result='draw'
#
# Game 53: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'black pawn', 'white pawn', 'white pawn', 'white pawn', 'white pawn', 'white rook'], ['white pawn', 'white pawn', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['axb3:w', 'b3:b', 'bxa3:w', 'a3:b', 'g4:w', 'a4:b', 'Kh1:w', 'Qb6:b', 'Qe3:w', 'b4:b', 'Nf3:w'] result='draw'
#
# Game 54: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', 'white pawn', 'white pawn', 'white pawn', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['cxb3:b', 'axb3:w', 'b3:b', 'bxa3:w', 'a3:b', 'g4:w', 'a4:b', 'Kh1:w', 'Qb6:b', 'Qe3:w', 'b4:b'] result='draw'
#
# Game 55: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', 'black pawn', '.', 'black pawn'], ['.', '.', '.', '.', '.', '.', 'white pawn', '.'], ['.', '.', '.', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['g5:w', 'cxb3:b', 'axb3:w', 'b3:b', 'bxa3:w', 'a3:b', 'g4:w', 'a4:b', 'Kh1:w', 'Qb6:b', 'Qe3:w'] result='draw'
#
# Game 56: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', '.', '.', 'black pawn'], ['.', '.', '.', '.', '.', 'black pawn', 'white pawn', '.'], ['.', '.', '.', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['f5:b', 'g5:w', 'cxb3:b', 'axb3:w', 'b3:b', 'bxa3:w', 'a3:b', 'g4:w', 'a4:b', 'Kh1:w', 'Qb6:b'] result='draw'
#
# Game 57: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', 'black pawn', '.'], ['.', 'black queen', '.', '.', 'black pawn', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'black pawn', '.', '.'], ['.', '.', '.', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['gxh6:w', 'f5:b', 'g5:w', 'cxb3:b', 'axb3:w', 'b3:b', 'bxa3:w', 'a3:b', 'g4:w', 'a4:b', 'Kh1:w'] result='draw'
#
# Game 58: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', '.', '.'], ['.', 'black queen', '.', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'black pawn', '.', '.'], ['.', '.', '.', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', 'white knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['g6:b', 'gxh6:w', 'f5:b', 'g5:w', 'cxb3:b', 'axb3:w', 'b3:b', 'bxa3:w', 'a3:b', 'g4:w', 'a4:b'] result='draw'
#
# Game 59: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', 'black bishop', '.', '.', '.', '.', '.', '.'], ['.', 'black queen', '.', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'black pawn', 'white knight', '.'], ['.', '.', '.', 'white pawn', 'white pawn', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['Ng5:w', 'g6:b', 'gxh6:w', 'f5:b', 'g5:w', 'cxb3:b', 'axb3:w', 'b3:b', 'bxa3:w', 'a3:b', 'g4:w'] result='draw'
#
# Game 60: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black queen', '.', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'black pawn', 'white knight', '.'], ['.', '.', '.', 'white pawn', 'black bishop', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['Bxe4+:b', 'Ng5:w', 'g6:b', 'gxh6:w', 'f5:b', 'g5:w', 'cxb3:b', 'axb3:w', 'b3:b', 'bxa3:w', 'a3:b'] result='draw'
#
# Game 61: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black queen', '.', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', 'black pawn', '.', '.'], ['.', '.', '.', 'white pawn', 'white knight', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['Nxe4:w', 'Bxe4+:b', 'Ng5:w', 'g6:b', 'gxh6:w', 'f5:b', 'g5:w', 'cxb3:b', 'axb3:w', 'b3:b', 'bxa3:w'] result='draw'
#
# Game 62: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black queen', '.', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', 'black pawn', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', 'white queen', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['fxe4:b', 'Nxe4:w', 'Bxe4+:b', 'Ng5:w', 'g6:b', 'gxh6:w', 'f5:b', 'g5:w', 'cxb3:b', 'axb3:w', 'b3:b'] result='draw'
#
# Game 63: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black queen', '.', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', 'white queen', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['Qxe4:w', 'fxe4:b', 'Nxe4:w', 'Bxe4+:b', 'Ng5:w', 'g6:b', 'gxh6:w', 'f5:b', 'g5:w', 'cxb3:b', 'axb3:w'] result='draw'
#
# Game 64: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'black queen', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', 'white queen', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['Qc6:b', 'Qxe4:w', 'fxe4:b', 'Nxe4:w', 'Bxe4+:b', 'Ng5:w', 'g6:b', 'gxh6:w', 'f5:b', 'g5:w', 'cxb3:b'] result='draw'
#
# Game 65: board=[['.', '.', 'black rook', '.', '.', 'black rook', '.', 'black king'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white queen', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['Qxc6:w', 'Qc6:b', 'Qxe4:w', 'fxe4:b', 'Nxe4:w', 'Bxe4+:b', 'Ng5:w', 'g6:b', 'gxh6:w', 'f5:b', 'g5:w'] result='draw'
#
# Game 66: board=[['.', '.', '.', '.', '.', 'black rook', '.', 'black king'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'black rook', '.', 'black pawn', '.', 'black pawn', 'white pawn'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'white pawn', '.', 'white pawn', '.', 'white rook'], ['white pawn', 'black pawn', 'white pawn', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white pawn'], ['.', '.', '.', '.', '.', 'white rook', '.', 'white king']] moves=['Rxc6:b', 'Qxc6:w', 'Qc6:b', 'Qxe4:w', 'fxe4:b', 'Nxe4:w', 'Bxe4+:b', 'Ng5:w', 'g6:b', 'gxh6:w', 'f5:b'] result='draw'
#
# ...
#
# Game 183: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', 'black bishop', 'black king', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black pawn', '.', 'black knight'], ['.', '.', '.', '.', 'white pawn', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white rook']] moves=['gxf5:b', 'f5:w', 'bxa2:b', 'Kxb2:w', 'Qxb2+:b', 'Qb2+:w', 'b3:b', 'f4:w', 'Nxh5:b', 'h5:w', 'Qa3:b'] result='black'
#
# Game 184: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', 'black bishop', 'black king', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'white pawn', '.', 'black knight'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white rook']] moves=['exf5:w', 'gxf5:b', 'f5:w', 'bxa2:b', 'Kxb2:w', 'Qxb2+:b', 'Qb2+:w', 'b3:b', 'f4:w', 'Nxh5:b', 'h5:w'] result='black'
#
# Game 185: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', 'black king', '.', '.'], ['.', '.', '.', '.', '.', 'white pawn', '.', 'black knight'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', 'white rook']] moves=['Kf6:b', 'exf5:w', 'gxf5:b', 'f5:w', 'bxa2:b', 'Kxb2:w', 'Qxb2+:b', 'Qb2+:w', 'b3:b', 'f4:w', 'Nxh5:b'] result='black'
#
# Game 186: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', 'black king', '.', '.'], ['.', '.', '.', '.', '.', 'white pawn', '.', 'black knight'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.']] moves=['Rc1:w', 'Kf6:b', 'exf5:w', 'gxf5:b', 'f5:w', 'bxa2:b', 'Kxb2:w', 'Qxb2+:b', 'Qb2+:w', 'b3:b', 'f4:w'] result='black'
#
# Game 187: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', 'black king', '.', '.'], ['black pawn', '.', '.', '.', '.', 'white pawn', '.', 'black knight'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.']] moves=['a5:b', 'Rc1:w', 'Kf6:b', 'exf5:w', 'gxf5:b', 'f5:w', 'bxa2:b', 'Kxb2:w', 'Qxb2+:b', 'Qb2+:w', 'b3:b'] result='black'
#
# Game 188: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', 'white rook', '.', '.', 'black king', '.', '.'], ['black pawn', '.', '.', '.', '.', 'white pawn', '.', 'black knight'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc6+:w', 'a5:b', 'Rc1:w', 'Kf6:b', 'exf5:w', 'gxf5:b', 'f5:w', 'bxa2:b', 'Kxb2:w', 'Qxb2+:b', 'Qb2+:w'] result='black'
#
# Game 189: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', 'white pawn', 'black king', 'black knight'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.']] moves=['Kg5:b', 'Rc6+:w', 'a5:b', 'Rc1:w', 'Kf6:b', 'exf5:w', 'gxf5:b', 'f5:w', 'bxa2:b', 'Kxb2:w', 'Qxb2+:b'] result='black'
#
# Game 190: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['white rook', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', 'white pawn', 'black king', 'black knight'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.']] moves=['Ra6:w', 'Kg5:b', 'Rc6+:w', 'a5:b', 'Rc1:w', 'Kf6:b', 'exf5:w', 'gxf5:b', 'f5:w', 'bxa2:b', 'Kxb2:w'] result='black'
#
# Game 191: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['white rook', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', 'white pawn', 'black king', '.'], ['.', '.', '.', '.', '.', 'black knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.']] moves=['Nf4:b', 'Ra6:w', 'Kg5:b', 'Rc6+:w', 'a5:b', 'Rc1:w', 'Kf6:b', 'exf5:w', 'gxf5:b', 'f5:w', 'bxa2:b'] result='black'
#
# Game 192: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['white rook', '.', '.', '.', '.', 'white pawn', 'black king', '.'], ['.', '.', '.', '.', '.', 'black knight', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.']] moves=['Rxa5:w', 'Nf4:b', 'Ra6:w', 'Kg5:b', 'Rc6+:w', 'a5:b', 'Rc1:w', 'Kf6:b', 'exf5:w', 'gxf5:b', 'f5:w'] result='black'
#
# Game 193: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['white rook', '.', '.', '.', '.', 'white pawn', 'black king', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'black knight', '.', '.', '.', '.'], ['black pawn', 'white king', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.']] moves=['Nd3+:b', 'Rxa5:w', 'Nf4:b', 'Ra6:w', 'Kg5:b', 'Rc6+:w', 'a5:b', 'Rc1:w', 'Kf6:b', 'exf5:w', 'gxf5:b'] result='black'
#
# Game 194: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['white rook', '.', '.', '.', '.', 'white pawn', 'black king', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'black knight', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Ka1:w', 'Nd3+:b', 'Rxa5:w', 'Nf4:b', 'Ra6:w', 'Kg5:b', 'Rc6+:w', 'a5:b', 'Rc1:w', 'Kf6:b', 'exf5:w'] result='black'
#
# Game 195: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['white rook', '.', '.', '.', '.', 'white pawn', 'black king', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Nb4:b', 'Ka1:w', 'Nd3+:b', 'Rxa5:w', 'Nf4:b', 'Ra6:w', 'Kg5:b', 'Rc6+:w', 'a5:b', 'Rc1:w', 'Kf6:b'] result='black'
#
# Game 196: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', 'white pawn', 'black king', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc5:w', 'Nb4:b', 'Ka1:w', 'Nd3+:b', 'Rxa5:w', 'Nf4:b', 'Ra6:w', 'Kg5:b', 'Rc6+:w', 'a5:b', 'Rc1:w'] result='black'
#
# Game 197: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', 'white pawn', 'black king', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', 'black bishop', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Bb3:b', 'Rc5:w', 'Nb4:b', 'Ka1:w', 'Nd3+:b', 'Rxa5:w', 'Nf4:b', 'Ra6:w', 'Kg5:b', 'Rc6+:w', 'a5:b'] result='black'
#
# Game 198: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'white pawn', 'black king', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', 'black bishop', 'white rook', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc3:w', 'Bb3:b', 'Rc5:w', 'Nb4:b', 'Ka1:w', 'Nd3+:b', 'Rxa5:w', 'Nf4:b', 'Ra6:w', 'Kg5:b', 'Rc6+:w'] result='black'
#
# Game 199: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', 'black bishop', '.', 'white pawn', 'black king', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Bd5:b', 'Rc3:w', 'Bb3:b', 'Rc5:w', 'Nb4:b', 'Ka1:w', 'Nd3+:b', 'Rxa5:w', 'Nf4:b', 'Ra6:w', 'Kg5:b'] result='black'
#
# Game 200: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', 'black bishop', '.', 'white pawn', 'black king', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc5:w', 'Bd5:b', 'Rc3:w', 'Bb3:b', 'Rc5:w', 'Nb4:b', 'Ka1:w', 'Nd3+:b', 'Rxa5:w', 'Nf4:b', 'Ra6:w'] result='black'
#
# Game 201: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', 'white pawn', 'black king', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Bf7:b', 'Rc5:w', 'Bd5:b', 'Rc3:w', 'Bb3:b', 'Rc5:w', 'Nb4:b', 'Ka1:w', 'Nd3+:b', 'Rxa5:w', 'Nf4:b'] result='black'
#
# Game 202: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'white pawn', 'black king', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc3:w', 'Bf7:b', 'Rc5:w', 'Bd5:b', 'Rc3:w', 'Bb3:b', 'Rc5:w', 'Nb4:b', 'Ka1:w', 'Nd3+:b', 'Rxa5:w'] result='black'
#
# Game 203: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black king', '.', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Kxf5:b', 'Rc3:w', 'Bf7:b', 'Rc5:w', 'Bd5:b', 'Rc3:w', 'Bb3:b', 'Rc5:w', 'Nb4:b', 'Ka1:w', 'Nd3+:b'] result='black'
#
# Game 204: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', 'black bishop', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black king', '.', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc7:w', 'Kxf5:b', 'Rc3:w', 'Bf7:b', 'Rc5:w', 'Bd5:b', 'Rc3:w', 'Bb3:b', 'Rc5:w', 'Nb4:b', 'Ka1:w'] result='black'
#
# Game 205: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'black bishop', '.', '.', '.'], ['.', '.', '.', '.', '.', 'black king', '.', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Be6:b', 'Rc7:w', 'Kxf5:b', 'Rc3:w', 'Bf7:b', 'Rc5:w', 'Bd5:b', 'Rc3:w', 'Bb3:b', 'Rc5:w', 'Nb4:b'] result='black'
#
# Game 206: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'black bishop', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', 'black king', '.', '.'], ['.', 'black knight', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc5+:w', 'Be6:b', 'Rc7:w', 'Kxf5:b', 'Rc3:w', 'Bf7:b', 'Rc5:w', 'Bd5:b', 'Rc3:w', 'Bb3:b', 'Rc5:w'] result='black'
#
# Game 207: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'black bishop', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['.', 'black knight', '.', '.', 'black king', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Ke4:b', 'Rc5+:w', 'Be6:b', 'Rc7:w', 'Kxf5:b', 'Rc3:w', 'Bf7:b', 'Rc5:w', 'Bd5:b', 'Rc3:w', 'Bb3:b'] result='black'
#
# Game 208: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'black bishop', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black knight', '.', '.', 'black king', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc3:w', 'Ke4:b', 'Rc5+:w', 'Be6:b', 'Rc7:w', 'Kxf5:b', 'Rc3:w', 'Bf7:b', 'Rc5:w', 'Bd5:b', 'Rc3:w'] result='black'
#
# Game 209: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'black bishop', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black knight', '.', 'black king', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Kd4:b', 'Rc3:w', 'Ke4:b', 'Rc5+:w', 'Be6:b', 'Rc7:w', 'Kxf5:b', 'Rc3:w', 'Bf7:b', 'Rc5:w', 'Bd5:b'] result='black'
#
# Game 210: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'black bishop', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black knight', '.', 'black king', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Rc7:w', 'Kd4:b', 'Rc3:w', 'Ke4:b', 'Rc5+:w', 'Be6:b', 'Rc7:w', 'Kxf5:b', 'Rc3:w', 'Bf7:b', 'Rc5:w'] result='black'
#
# Game 211: board=[['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'white rook', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'black knight', 'black bishop', 'black king', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['black pawn', '.', '.', '.', '.', '.', '.', '.'], ['white king', '.', '.', '.', '.', '.', '.', '.']] moves=['Bc4:b', 'Rc7:w', 'Kd4:b', 'Rc3:w', 'Ke4:b', 'Rc5+:w', 'Be6:b', 'Rc7:w', 'Kxf5:b', 'Rc3:w', 'Bf7:b'] result='black'

# %%
len(possible_moves)
# Out:
# 154

# %%
games: list[GameState] = []
files = os.listdir("data/raw")
possible_moves = set()
for file in files[:1]:
    print(file)
    games, possible_moves = extract_formatted_games_from_pgn(f"data/raw/{file}", possible_moves, 1_000)
    games.extend(games)
    print(f'{len(games)} games')
# Save games to a JSON file

# Create the output directory if it doesn't exist
json_output_file = "data/processed/games.json"
os.makedirs(os.path.dirname(json_output_file), exist_ok=True)

# Write games to the JSON file using Pydantic's json_dumps method
with open(json_output_file, 'w', encoding='utf-8') as f:
    # Convert list of GameState objects to JSON using Pydantic's json method
    games_json = [game.model_dump_json() for game in games]
    # Write as a JSON array
    f.write("[\n")
    f.write(",\n".join(games_json))
    f.write("\n]")

print(f"Saved {len(games)} games to {json_output_file}")
# Out:
# lichess_elite_2022-04.pgn
# 0 games
# 100 games
# 200 games
# 300 games
# 400 games
# 500 games
# 600 games
# 700 games
# 800 games
# 900 games
# 163674 games
# Saved 163674 games to data/processed/games.json

# %%
# Save possible moves to a text file
moves_output_file = "data/processed/possible_moves.txt"
os.makedirs(os.path.dirname(moves_output_file), exist_ok=True)

# Write moves to the text file with space delimiter
with open(moves_output_file, 'w', encoding='utf-8') as f:
    f.write(' '.join(possible_moves))

print(f"Saved {len(possible_moves)} possible moves to {moves_output_file}")
len(possible_moves)

# Read the saved possible moves from the text file
def read_possible_moves_from_txt(txt_file_path):
    """
    Read possible moves from a text file
    """
    with open(txt_file_path, 'r', encoding='utf-8') as f:
        content = f.read()
    
    # Split by space to get individual moves
    possible_moves = set(content.split())
    return possible_moves

# Example usage
loaded_moves = read_possible_moves_from_txt("data/processed/possible_moves.txt")
print(f"Loaded {len(loaded_moves)} possible moves from text file")
# Out:
# Saved 2007 possible moves to data/processed/possible_moves.txt
# Loaded 2007 possible moves from text file

# %%
from typing import Callable

EMPTY = '.'

# Read the processed game file
with open("data/processed/chess_games.txt", 'r', encoding='utf-8') as f:
    processed_games = f.read().splitlines()

# Create character-to-index mapping from the processed games
tokens = ' '.join(processed_games).split(' ')
stoi = {ch: i for i, ch in enumerate(set(tokens))}
itos = {i: ch for ch, i in stoi.items()}

encode: Callable[[str], list[int]] = lambda s: [stoi[c] for c in s]
decode: Callable[[list[int]], str] = lambda l: ''.join([itos[i] for i in l])
vocab_size = len(stoi)
context_length = max([len(g) for g in processed_games])
print(f'{context_length=}')
print(f'{len(stoi)=}')
stoi

# %%
def get_chess_elements():
    # All possible pieces (6 types × 2 colors + empty square)
    pieces = {
        'white pawn', 'white rook', 'white knight', 'white bishop', 'white queen', 'white king',
        'black pawn', 'black rook', 'black knight', 'black bishop', 'black queen', 'black king',
        '.'  # empty square
    }
    
    # Standard algebraic notation + color suffix patterns
    # Real games will have specific instances of these patterns
    move_patterns = {
        # Basic piece moves: e4:w, Nf3:b, etc.
        f"{file}{rank}:{color}" for file in 'abcdefgh' for rank in '12345678' for color in 'wb'
    } | {
        f"{piece}{file}{rank}:{color}" for piece in 'NBRQK' for file in 'abcdefgh' 
        for rank in '12345678' for color in 'wb'
    } | {
        # Castling: O-O:w, O-O-O:b
        f"{castle}:{color}" for castle in ['O-O', 'O-O-O'] for color in 'wb'
    }
    
    return pieces, move_patterns

# Get the elements
pieces, moves = get_chess_elements()

print(f"Pieces ({len(pieces)}): {sorted(pieces)}")
print(f"Number of basic move patterns: {len(moves)} {moves}")
# Out:
# Pieces (13): ['.', 'black bishop', 'black king', 'black knight', 'black pawn', 'black queen', 'black rook', 'white bishop', 'white king', 'white knight', 'white pawn', 'white queen', 'white rook']
# Number of basic move patterns: 772 {'Kb2:w', 'Bc5:b', 'Bd1:b', 'Kg2:b', 'Bd2:b', 'Rf5:w', 'Qe8:w', 'Bh7:b', 'h5:b', 'Ke3:w', 'Ke5:b', 'Rf2:b', 'f3:b', 'Kf4:b', 'f5:w', 'Ka1:b', 'Bh4:b', 'Re1:w', 'f5:b', 'Bc4:w', 'Nf2:b', 'g7:w', 'Re6:b', 'Qb6:w', 'Be4:b', 'Nd5:w', 'Qh1:b', 'Kf2:b', 'b8:b', 'c2:w', 'Bf3:b', 'Bg3:b', 'Nf6:w', 'Rh1:b', 'b3:b', 'Na8:w', 'Nf8:w', 'Bg2:b', 'Kb7:w', 'Nb1:w', 'Nc1:b', 'g5:w', 'Kf5:w', 'd1:b', 'Bf8:w', 'Qc7:b', 'Bg4:w', 'Bg2:w', 'Ka2:b', 'Qg1:w', 'f3:w', 'Qg7:b', 'Rd4:w', 'Kg6:w', 'Kb1:b', 'Bg5:w', 'a6:b', 'Bc2:w', 'Rc3:b', 'Bd6:w', 'Rb6:w', 'Kb3:w', 'Qa7:w', 'e8:w', 'Be3:w', 'Rg7:w', 'Ne4:b', 'Kh3:b', 'Re8:b', 'Rb1:b', 'Qa8:b', 'Bd7:w', 'Qd3:w', 'Rf5:b', 'Rf8:b', 'Ra7:w', 'a3:w', 'Re3:b', 'Rh8:w', 'Qe5:w', 'h3:b', 'Bh3:w', 'a2:w', 'e7:b', 'Qc1:b', 'Nc5:w', 'Ng2:w', 'Rg5:w', 'Ra3:w', 'Qa4:w', 'd2:b', 'Bg1:w', 'Rf1:w', 'Qh3:b', 'Ne3:w', 'Ra4:w', 'Re6:w', 'h2:w', 'Bb5:w', 'Bh1:w', 'Kb5:b', 'Rb6:b', 'a3:b', 'Ra7:b', 'Ra5:w', 'Bd5:b', 'Qc5:w', 'b1:w', 'e4:b', 'Rd3:w', 'Kc2:b', 'Kh3:w', 'Ka3:w', 'Qa1:w', 'Rb2:b', 'e3:w', 'Kd3:w', 'Ra5:b', 'Rh6:b', 'Be5:b', 'Ke1:b', 'Bg8:b', 'h2:b', 'e6:b', 'Na3:b', 'g3:b', 'a5:b', 'Bb1:w', 'Qe7:b', 'Kg3:b', 'Ke8:b', 'O-O-O:b', 'Rg3:b', 'Ng4:w', 'h5:w', 'd5:b', 'Qa2:w', 'Bb8:w', 'Kh5:w', 'Kh8:b', 'e2:b', 'b2:b', 'Qb4:b', 'Rd7:w', 'e3:b', 'c5:b', 'Nf4:w', 'Rf2:w', 'Qc2:b', 'd4:w', 'Qb5:b', 'Bc6:b', 'Bc7:w', 'Kf6:b', 'Nd7:b', 'Qc8:b', 'Qf2:b', 'Nb8:w', 'Qg2:b', 'Bd3:w', 'O-O-O:w', 'Nc1:w', 'Na2:b', 'Qg2:w', 'Qh1:w', 'Qc2:w', 'Qd1:b', 'Kb7:b', 'b4:b', 'Rg3:w', 'Nd1:b', 'Qe1:w', 'Qc4:b', 'c3:b', 'Qd5:w', 'Bf1:b', 'Nf2:w', 'd5:w', 'Ba3:w', 'Bb4:w', 'Kd6:b', 'Qf2:w', 'Qf5:b', 'Nf3:b', 'b8:w', 'Qb3:b', 'Nf4:b', 'e5:w', 'Nd4:b', 'Ne2:b', 'Ke8:w', 'Bf1:w', 'Qc5:b', 'Rd5:b', 'Rf6:b', 'Rg2:b', 'Qd6:b', 'Rg7:b', 'Rc5:b', 'Kc5:b', 'Be3:b', 'Kd1:b', 'Ne1:b', 'b1:b', 'Nb4:b', 'Qe6:w', 'g4:b', 'Nd2:w', 'Nc4:w', 'Bh8:b', 'Nc7:b', 'Rh3:b', 'Rh6:w', 'Qf4:b', 'Kd7:w', 'Kb3:b', 'Kd7:b', 'Rb4:w', 'Kf8:w', 'Bf8:b', 'Nc4:b', 'b5:w', 'Nf6:b', 'c6:b', 'Nb2:w', 'Ba6:b', 'Ba8:w', 'Qa5:b', 'a7:w', 'Qb2:b', 'Bd3:b', 'Qf7:w', 'Bd6:b', 'h6:w', 'Ng4:b', 'Ng5:w', 'Bf7:w', 'Ka1:w', 'Kg7:b', 'Be1:w', 'Rd8:b', 'Kh2:b', 'Qb1:w', 'Bh6:w', 'Rc2:w', 'Rg1:w', 'Bg6:w', 'Nb6:w', 'Ng7:b', 'Ka7:b', 'Bf5:w', 'Qh8:b', 'Qe5:b', 'Qg1:b', 'Re8:w', 'Rh2:b', 'Kc7:w', 'Kb1:w', 'Bc2:b', 'Kf6:w', 'Nb1:b', 'Ra6:b', 'Kb4:b', 'Kd4:b', 'Be7:w', 'Ne6:w', 'Kg5:w', 'Kg7:w', 'Kf1:w', 'Nc3:b', 'Ke6:w', 'Rf3:b', 'b7:w', 'Qc4:w', 'Bg8:w', 'Bf3:w', 'h1:b', 'Be6:b', 'Rf4:w', 'Kb6:w', 'Ba3:b', 'Rg1:b', 'Na3:w', 'Ne8:w', 'Kd8:b', 'd7:b', 'h8:w', 'Qg3:w', 'Bh1:b', 'a7:b', 'g1:w', 'a8:b', 'Ka4:b', 'Be2:b', 'Rb2:w', 'c8:b', 'Qe8:b', 'Bc1:b', 'Rc8:b', 'Qf1:w', 'Re2:w', 'Ke7:w', 'd6:b', 'h7:w', 'Ba7:b', 'Bf2:w', 'g2:b', 'c8:w', 'Nd1:w', 'Rg4:b', 'Rh7:w', 'Qg6:w', 'Bb6:b', 'Nh4:b', 'Ne2:w', 'Rc6:w', 'e8:b', 'Bh3:b', 'Ra4:b', 'Rf3:w', 'Qf3:w', 'Ba2:b', 'Bc8:b', 'Bd5:w', 'Kc5:w', 'Kg6:b', 'Rf1:b', 'Bb4:b', 'Kd4:w', 'Qa8:w', 'Kc8:b', 'Qg3:b', 'Qh7:b', 'Ka7:w', 'Qd8:w', 'Kc4:b', 'Bh8:w', 'Qh3:w', 'c7:w', 'Ra8:b', 'Rf6:w', 'Nh5:w', 'd6:w', 'Bb2:b', 'Rd1:w', 'Rg6:b', 'Kc6:b', 'd8:w', 'Kc8:w', 'a6:w', 'Rc4:b', 'Nc5:b', 'Qa5:w', 'a4:b', 'Ne3:b', 'Nb6:b', 'Rd1:b', 'Ng1:w', 'Rd4:b', 'g6:w', 'h8:b', 'Qh4:b', 'Kg4:b', 'Kg3:w', 'g6:b', 'd2:w', 'Bh5:b', 'b6:w', 'Ba5:b', 'Bc7:b', 'Qe4:b', 'Rg4:w', 'Nf1:b', 'Qd8:b', 'Rc1:w', 'Ne4:w', 'Qg8:b', 'Bg5:b', 'Ng8:w', 'Ka6:w', 'Qb1:b', 'Nd3:b', 'Na8:b', 'Bb7:w', 'a4:w', 'Bh7:w', 'Qb7:b', 'Kc3:b', 'Bh5:w', 'Qf6:w', 'Qf7:b', 'Ne5:w', 'Rh8:b', 'Kg8:w', 'Rh2:w', 'Qe3:w', 'Rb7:w', 'f2:b', 'Nf5:b', 'Nh3:w', 'Rg6:w', 'e4:w', 'Rb8:w', 'Ke1:w', 'Re4:b', 'Ne8:b', 'Ka6:b', 'Nb3:b', 'Bg7:b', 'Nc7:w', 'Qh6:w', 'Rb3:w', 'Qa2:b', 'Qd7:b', 'Na6:b', 'Rd2:b', 'Ba1:b', 'Rh3:w', 'Nd2:b', 'Bb1:b', 'Rg2:w', 'Qe6:b', 'Kd5:w', 'Rb5:w', 'Ne6:b', 'Bc1:w', 'Rh1:w', 'Qa3:b', 'g2:w', 'g1:b', 'Re2:b', 'Ng5:b', 'h6:b', 'e6:w', 'f2:w', 'h4:w', 'Re7:w', 'Ke4:w', 'b3:w', 'Kg8:b', 'Ba8:b', 'Ba6:w', 'Ba2:w', 'Qc6:b', 'e7:w', 'Qg4:b', 'Kg5:b', 'Qf8:w', 'g7:b', ...

# %%
import chess
import numpy as np
from typing import List, Dict, Tuple, Union, Optional

class ChessFeatureEncoder:
    """
    Encodes chess moves as 12-dimensional feature vectors.
    
    Feature dimensions:
    0: piece type (0-5, representing pawn=0, knight=1, bishop=2, rook=3, queen=4, king=5)
    1: from_file (0-7, representing a-h)
    2: from_rank (0-7, representing 1-8)
    3: to_file (0-7, representing a-h)
    4: to_rank (0-7, representing 1-8)
    5: is_capture (0 or 1)
    6: is_check (0 or 1)
    7: is_checkmate (0 or 1)
    8: is_promotion (0 or 1)
    9: promotion_piece (0-3, representing queen=0, rook=1, bishop=2, knight=3, or -1 if not a promotion)
    10: is_castle_kingside (0 or 1)
    11: is_castle_queenside (0 or 1)
    """
    
    def __init__(self):
        # Mapping from piece type to integer (0-5)
        self.piece_to_int = {
            chess.PAWN: 0,
            chess.KNIGHT: 1,
            chess.BISHOP: 2,
            chess.ROOK: 3, 
            chess.QUEEN: 4,
            chess.KING: 5
        }
        
        # Mapping from integer to piece type
        self.int_to_piece = {v: k for k, v in self.piece_to_int.items()}
        
        # Mapping from promotion piece to integer (0-3)
        self.promotion_to_int = {
            chess.QUEEN: 0,
            chess.ROOK: 1,
            chess.BISHOP: 2,
            chess.KNIGHT: 3
        }
        
        # Mapping from integer to promotion piece
        self.int_to_promotion = {v: k for k, v in self.promotion_to_int.items()}
    
    def encode_move(self, board: chess.Board, move: chess.Move) -> np.ndarray:
        """
        Encode a chess move as a 12-dimensional feature vector.
        
        Args:
            board: The current chess board
            move: The move to encode
            
        Returns:
            np.ndarray: 12-dimensional feature vector
        """
        # Initialize feature vector with zeros
        features = np.zeros(12, dtype=np.int8)
        
        # Get piece type
        piece = board.piece_at(move.from_square)
        if piece is None:
            raise ValueError(f"No piece at source square {chess.square_name(move.from_square)}")
        
        features[0] = self.piece_to_int[piece.piece_type]
        
        # Get source square (file and rank)
        features[1] = chess.square_file(move.from_square)  # 0-7 for a-h
        features[2] = chess.square_rank(move.from_square)  # 0-7 for 1-8
        
        # Get destination square (file and rank)
        features[3] = chess.square_file(move.to_square)    # 0-7 for a-h
        features[4] = chess.square_rank(move.to_square)    # 0-7 for 1-8
        
        # Check if the move is a capture
        features[5] = int(board.is_capture(move))
        
        # We need to make the move temporarily to check if it results in check or checkmate
        board.push(move)
        features[6] = int(board.is_check())
        features[7] = int(board.is_checkmate() if features[6] else 0)  # Checkmate implies check
        board.pop()
        
        # Check if the move is a promotion
        features[8] = int(move.promotion is not None)
        features[9] = self.promotion_to_int.get(move.promotion, -1)  # -1 if not a promotion
        
        # Check if the move is castling
        # Kingside castling
        if piece.piece_type == chess.KING and move.from_square == chess.E1 and move.to_square == chess.G1:
            features[10] = 1
        elif piece.piece_type == chess.KING and move.from_square == chess.E8 and move.to_square == chess.G8:
            features[10] = 1
        # Queenside castling
        elif piece.piece_type == chess.KING and move.from_square == chess.E1 and move.to_square == chess.C1:
            features[11] = 1
        elif piece.piece_type == chess.KING and move.from_square == chess.E8 and move.to_square == chess.C8:
            features[11] = 1
        
        return features
    
    def encode_uci(self, board: chess.Board, uci: str) -> np.ndarray:
        """
        Encode a UCI move string as a 12-dimensional feature vector.
        
        Args:
            board: The current chess board
            uci: UCI move string (e.g., "e2e4", "e7e8q")
            
        Returns:
            np.ndarray: 12-dimensional feature vector
        """
        move = chess.Move.from_uci(uci)
        return self.encode_move(board, move)
    
    def encode_san(self, board: chess.Board, san: str) -> np.ndarray:
        """
        Encode a SAN move string as a 12-dimensional feature vector.
        
        Args:
            board: The current chess board
            san: SAN move string (e.g., "e4", "Nf3", "O-O")
            
        Returns:
            np.ndarray: 12-dimensional feature vector
        """
        move = board.parse_san(san)
        return self.encode_move(board, move)
    
    def decode_to_uci(self, board: chess.Board, features: np.ndarray) -> Optional[str]:
        """
        Attempt to decode a feature vector back to a UCI move string.
        
        Args:
            board: The current chess board
            features: 12-dimensional feature vector
            
        Returns:
            str: UCI move string, or None if no valid move could be found
        """
        # Extract basic move information
        piece_type = self.int_to_piece[features[0]]
        from_file = features[1]
        from_rank = features[2]
        to_file = features[3]
        to_rank = features[4]
        is_promotion = bool(features[8])
        
        # Calculate source and destination squares
        from_square = chess.square(from_file, from_rank)
        to_square = chess.square(to_file, to_rank)
        
        # Handle promotion
        promotion = None
        if is_promotion:
            promotion_idx = features[9]
            if promotion_idx >= 0:
                promotion = self.int_to_promotion[promotion_idx]
        
        # Create the move
        move = chess.Move(from_square, to_square, promotion)
        
        # Verify that this is a legal move
        if move in board.legal_moves:
            return move.uci()
        else:
            # Try to find a similar legal move
            for legal_move in board.legal_moves:
                if (legal_move.from_square == from_square and 
                    legal_move.to_square == to_square):
                    return legal_move.uci()
        
        return None
    
    def get_all_legal_moves_encoded(self, board: chess.Board) -> Dict[str, np.ndarray]:
        """
        Get all legal moves from the current position, encoded as feature vectors.
        
        Args:
            board: The current chess board
            
        Returns:
            Dict[str, np.ndarray]: Dictionary mapping UCI strings to feature vectors
        """
        encoded_moves = {}
        
        for move in board.legal_moves:
            uci = move.uci()
            features = self.encode_move(board, move)
            encoded_moves[uci] = features
        
        return encoded_moves

def demonstrate_encoding():
    """
    Demonstrate the feature encoding on various chess positions.
    """
    encoder = ChessFeatureEncoder()
    
    # Create a board with the starting position
    board = chess.Board()
    
    # Get all legal moves and their encodings
    encoded_moves = encoder.get_all_legal_moves_encoded(board)
    
    print(f"Number of legal moves from starting position: {len(encoded_moves)}")
    print("\nSample encodings:")
    
    # Show a few examples
    for uci, features in list(encoded_moves.items())[:5]:
        move = chess.Move.from_uci(uci)
        san = board.san(move)
        print(f"Move: {san} (UCI: {uci})")
        print(f"Features: {features}")
        print(f"- Piece: {['Pawn', 'Knight', 'Bishop', 'Rook', 'Queen', 'King'][features[0]]}")
        print(f"- From: {chess.square_name(chess.square(features[1], features[2]))}")
        print(f"- To: {chess.square_name(chess.square(features[3], features[4]))}")
        print(f"- Capture: {bool(features[5])}")
        print(f"- Check: {bool(features[6])}")
        print(f"- Checkmate: {bool(features[7])}")
        print(f"- Promotion: {bool(features[8])}")
        if features[8]:
            promotion_type = ['Queen', 'Rook', 'Bishop', 'Knight'][features[9]]
            print(f"- Promotion piece: {promotion_type}")
        print(f"- Castling: {['None', 'Kingside', 'Queenside', 'Both'][int(features[10]) + 2*int(features[11])]}")
        print()
    
    # Demonstrate on a more complex position with special moves
    print("\nDemonstrating on a position with special moves:")
    # A position with potential captures, promotions, and checks
    board = chess.Board("r1bqkb1r/pPpp1ppp/2n2n2/4p3/2B1P3/5N2/PPPP1PPP/RNBQK2R w KQkq - 0 5")
    print(board)
    
    encoded_moves = encoder.get_all_legal_moves_encoded(board)
    
    # Look for interesting moves to demonstrate
    special_moves = []
    for uci, features in encoded_moves.items():
        # Look for captures, promotions, or castling
        if features[5] or features[8] or features[10] or features[11]:
            special_moves.append((uci, features))
    
    print("\nInteresting moves from this position:")
    for uci, features in special_moves[:5]:  # Show up to 5
        move = chess.Move.from_uci(uci)
        san = board.san(move)
        print(f"Move: {san} (UCI: {uci})")
        print(f"Features: {features}")
        
        # Describe the move
        description = []
        if features[10]:
            description.append("kingside castling")
        elif features[11]:
            description.append("queenside castling")
        
        if features[5]:
            description.append("capture")
            
        if features[8]:
            promotion_type = ['Queen', 'Rook', 'Bishop', 'Knight'][features[9]]
            description.append(f"promotion to {promotion_type}")
            
        if features[6]:
            description.append("check")
        if features[7]:
            description.append("checkmate")
            
        print(f"This is a {', '.join(description)} move")
        print()

demonstrate_encoding()
# Out:
# Number of legal moves from starting position: 20
#
# Sample encodings:
# Move: Nh3 (UCI: g1h3)
# Features: [ 1  6  0  7  2  0  0  0  0 -1  0  0]
# - Piece: Knight
# - From: g1
# - To: h3
# - Capture: False
# - Check: False
# - Checkmate: False
# - Promotion: False
# - Castling: None
#
# Move: Nf3 (UCI: g1f3)
# Features: [ 1  6  0  5  2  0  0  0  0 -1  0  0]
# - Piece: Knight
# - From: g1
# - To: f3
# - Capture: False
# - Check: False
# - Checkmate: False
# - Promotion: False
# - Castling: None
#
# Move: Nc3 (UCI: b1c3)
# Features: [ 1  1  0  2  2  0  0  0  0 -1  0  0]
# - Piece: Knight
# - From: b1
# - To: c3
# - Capture: False
# - Check: False
# - Checkmate: False
# - Promotion: False
# - Castling: None
#
# Move: Na3 (UCI: b1a3)
# Features: [ 1  1  0  0  2  0  0  0  0 -1  0  0]
# - Piece: Knight
# - From: b1
# - To: a3
# - Capture: False
# - Check: False
# - Checkmate: False
# - Promotion: False
# - Castling: None
#
# Move: h3 (UCI: h2h3)
# Features: [ 0  7  1  7  2  0  0  0  0 -1  0  0]
# - Piece: Pawn
# - From: h2
# - To: h3
# - Capture: False
# - Check: False
# - Checkmate: False
# - Promotion: False
# - Castling: None
#
#
# Demonstrating on a position with special moves:
# r . b q k b . r
# p P p p . p p p
# . . n . . n . .
# . . . . p . . .
# . . B . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K . . R
#
# Interesting moves from this position:
# Move: Bxf7+ (UCI: c4f7)
# Features: [ 2  2  3  5  6  1  1  0  0 -1  0  0]
# This is a capture, check move
#
# Move: Nxe5 (UCI: f3e5)
# Features: [ 1  5  2  4  4  1  0  0  0 -1  0  0]
# This is a capture move
#
# Move: O-O (UCI: e1g1)
# Features: [ 5  4  0  6  0  0  0  0  0 -1  1  0]
# This is a kingside castling move
#
# Move: bxc8=Q (UCI: b7c8q)
# Features: [0 1 6 2 7 1 0 0 1 0 0 0]
# This is a capture, promotion to Queen move
#
# Move: bxc8=R (UCI: b7c8r)
# Features: [0 1 6 2 7 1 0 0 1 1 0 0]
# This is a capture, promotion to Rook move
